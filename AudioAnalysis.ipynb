# %%
# %load_ext autoreload
# %autoreload 2

# %%
from AudioAnalysis import *

# %%
data_fpath = './file_read_write/L1.wav'
t, y, sr = read(data_fpath)
t = t[:44100*5]
y = y[44100*5:]

# %%
plot_temporal_analysis(t, y, sr)

# %%
plot_frequency_analysis(y, sr)
